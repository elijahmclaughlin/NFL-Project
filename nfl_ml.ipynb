# %%
import pandas as pd

# %%
# reading in dataset and cleaning

# %%
stats = pd.read_csv("team_stats.csv")

# %%
del stats ["Unnamed: 0"]

# %%
# checking for any null values so ML works

# %%
pd.isnull(stats).sum()
# Out:
# Tm                 0
# W                  0
# L                  0
# T                320
# W-L%               0
# PF                 0
# PA                 0
# PD                 0
# MoV                0
# SoS                0
# SRS                0
# OSRS               0
# DSRS               0
# Year               0
# Total Yards        0
# Ply                0
# Y/P                0
# TO                 0
# FL                 0
# 1stD               0
# Pen                0
# Penalty Yards      0
# 1stPy              0
# Sc%                0
# TO%                0
# Cmp                0
# Passing Att        0
# Cmp%               0
# Passing Yards      0
# Passing TD         0
# Int                0
# Passing Y/A        0
# Passing Y/G        0
# Sk                 0
# Passing EXP        0
# Rushing Att        0
# Rushing Yards      0
# Rushing TD         0
# Rushing Y/A        0
# Rushing Y/G        0
# Fmb                0
# Rushing EXP        0
# dtype: int64

# %%
stats[pd.isnull(stats["T"])][["Tm", "T"]]
# Out:
#                        Tm   T
# 32   New England Patriots NaN
# 33         Miami Dolphins NaN
# 34          Buffalo Bills NaN
# 35          New York Jets NaN
# 36       Baltimore Ravens NaN
# ..                    ...  ..
# 507  Tampa Bay Buccaneers NaN
# 508      Los Angeles Rams NaN
# 509      Seattle Seahawks NaN
# 510     Arizona Cardinals NaN
# 511   San Francisco 49ers NaN
#
# [320 rows x 2 columns]

# %%
# replacing null values with 0

# %%
stats = stats.fillna(0)

# %%
# double checking for any null values -- which there are none

# %%
pd.isnull(stats).sum()
# Out:
# Tm               0
# W                0
# L                0
# T                0
# W-L%             0
# PF               0
# PA               0
# PD               0
# MoV              0
# SoS              0
# SRS              0
# OSRS             0
# DSRS             0
# Year             0
# Total Yards      0
# Ply              0
# Y/P              0
# TO               0
# FL               0
# 1stD             0
# Pen              0
# Penalty Yards    0
# 1stPy            0
# Sc%              0
# TO%              0
# Cmp              0
# Passing Att      0
# Cmp%             0
# Passing Yards    0
# Passing TD       0
# Int              0
# Passing Y/A      0
# Passing Y/G      0
# Sk               0
# Passing EXP      0
# Rushing Att      0
# Rushing Yards    0
# Rushing TD       0
# Rushing Y/A      0
# Rushing Y/G      0
# Fmb              0
# Rushing EXP      0
# dtype: int64

# %%
# finding the correlation for "W", or "Win"'s

# %%
stats.corr()["W"]
# Out:
# /var/folders/y3/r0ps8vrx15l_2cq4rs9lkww40000gn/T/ipykernel_28616/3373071346.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stats.corr()["W"]
# W                1.000000
# L               -0.994025
# T               -0.076559
# W-L%             0.998357
# PF               0.747232
# PA              -0.647818
# PD               0.910204
# MoV              0.910262
# SoS             -0.195696
# SRS              0.874671
# OSRS             0.747535
# DSRS             0.622293
# Year             0.019203
# Total Yards      0.538386
# Ply              0.266504
# Y/P              0.525372
# TO              -0.504727
# FL              -0.304235
# 1stD             0.516143
# Pen             -0.119212
# Penalty Yards   -0.076774
# 1stPy            0.133098
# Sc%              0.679303
# TO%             -0.519259
# Cmp              0.160822
# Passing Att     -0.060213
# Cmp%             0.439522
# Passing Yards    0.356921
# Passing TD       0.529216
# Int             -0.477649
# Passing Y/A      0.544280
# Passing Y/G      0.353950
# Sk              -0.469332
# Passing EXP      0.608464
# Rushing Att      0.428639
# Rushing Yards    0.341569
# Rushing TD       0.480515
# Rushing Y/A      0.118973
# Rushing Y/G      0.343504
# Fmb             -0.315779
# Rushing EXP      0.054192
# Name: W, dtype: float64

# %%
# there is a strong correlation for most of the stats

# %%
stats.columns
# Out:
# Index(['Tm', 'W', 'L', 'T', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'SRS',
#        'OSRS', 'DSRS', 'Year', 'Total Yards', 'Ply', 'Y/P', 'TO', 'FL', '1stD',
#        'Pen', 'Penalty Yards', '1stPy', 'Sc%', 'TO%', 'Cmp', 'Passing Att',
#        'Cmp%', 'Passing Yards', 'Passing TD', 'Int', 'Passing Y/A',
#        'Passing Y/G', 'Sk', 'Passing EXP', 'Rushing Att', 'Rushing Yards',
#        'Rushing TD', 'Rushing Y/A', 'Rushing Y/G', 'Fmb', 'Rushing EXP'],
#       dtype='object')

# %%
# assigning predictors

# %%
predict = ['PF', 'PA', 'PD', 'MoV', 'SoS', 'SRS',
       'OSRS', 'DSRS', 'Total Yards', 'Ply', 'Y/P', 'TO', 'FL', '1stD',
       'Pen', 'Penalty Yards', '1stPy', 'Sc%', 'TO%', 'Cmp', 'Passing Att',
       'Cmp%', 'Passing Yards', 'Passing TD', 'Int', 'Passing Y/A',
       'Passing Y/G', 'Sk', 'Passing EXP', 'Rushing Att', 'Rushing Yards',
       'Rushing TD', 'Rushing Y/A', 'Rushing Y/G', 'Fmb', 'Rushing EXP']

# %%
train = stats[stats["Year"] < 2022]

# %%
test = stats[stats["Year"] == 2022]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
reg.fit(train[predict], train["W"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predict])

# %%
predictions = pd.DataFrame(predictions, columns=["predict"], index=test.index)

# %%
predictions
# Out:
#        predict
# 640  11.603745
# 641   8.941453
# 642   8.918529
# 643   7.341014
# 644  10.350324
# 645   7.897760
# 646   7.460570
# 647   6.908686
# 648   9.785982
# 649   6.406431
# 650   4.736960
# 651   5.725705
# 652  12.001776
# 653   9.399177
# 654   7.714112
# 655   6.256163
# 656  10.532708
# 657  11.194409
# 658   7.309861
# 659   7.681525
# 660   9.090638
# 661   9.538375
# 662   8.180089
# 663   2.605642
# 664   8.919538
# 665   7.084196
# 666   8.093090
# 667   7.035387
# 668  12.436656
# 669   8.555919
# 670   6.321592
# 671   5.414782

# %%
comb = pd.concat([test[["Tm", "W"]], predictions], axis=1)

# %%
comb
# Out:
#                         Tm   W    predict
# 640          Buffalo Bills  13  11.603745
# 641         Miami Dolphins   9   8.941453
# 642   New England Patriots   8   8.918529
# 643          New York Jets   7   7.341014
# 644     Cincinnati Bengals  12  10.350324
# 645       Baltimore Ravens  10   7.897760
# 646    Pittsburgh Steelers   9   7.460570
# 647       Cleveland Browns   7   6.908686
# 648   Jacksonville Jaguars   9   9.785982
# 649       Tennessee Titans   7   6.406431
# 650     Indianapolis Colts   4   4.736960
# 651         Houston Texans   3   5.725705
# 652     Kansas City Chiefs  14  12.001776
# 653   Los Angeles Chargers  10   9.399177
# 654      Las Vegas Raiders   6   7.714112
# 655         Denver Broncos   5   6.256163
# 656    Philadelphia Eagles  14  10.532708
# 657         Dallas Cowboys  12  11.194409
# 658        New York Giants   9   7.309861
# 659  Washington Commanders   8   7.681525
# 660      Minnesota Vikings  13   9.090638
# 661          Detroit Lions   9   9.538375
# 662      Green Bay Packers   8   8.180089
# 663          Chicago Bears   3   2.605642
# 664   Tampa Bay Buccaneers   8   8.919538
# 665      Carolina Panthers   7   7.084196
# 666     New Orleans Saints   7   8.093090
# 667        Atlanta Falcons   7   7.035387
# 668    San Francisco 49ers  13  12.436656
# 669       Seattle Seahawks   9   8.555919
# 670       Los Angeles Rams   5   6.321592
# 671      Arizona Cardinals   4   5.414782

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(comb["W"], comb["predict"])
# Out:
# 2.1233178003803364

# %%
comb = comb.sort_values("W", ascending=False)
comb["Rk"] = list(range(1,comb.shape[0]+1))

# %%
comb = comb.sort_values("predict", ascending=False)
comb["Predicted_Rk"] = list(range(1,comb.shape[0]+1))

# %%
comb
# Out:
#                         Tm   W    predict  Rk  Predicted_Rk
# 668    San Francisco 49ers  13  12.436656   3             1
# 652     Kansas City Chiefs  14  12.001776   2             2
# 640          Buffalo Bills  13  11.603745   5             3
# 657         Dallas Cowboys  12  11.194409   6             4
# 656    Philadelphia Eagles  14  10.532708   1             5
# 644     Cincinnati Bengals  12  10.350324   7             6
# 648   Jacksonville Jaguars   9   9.785982  15             7
# 661          Detroit Lions   9   9.538375  11             8
# 653   Los Angeles Chargers  10   9.399177   9             9
# 660      Minnesota Vikings  13   9.090638   4            10
# 641         Miami Dolphins   9   8.941453  13            11
# 664   Tampa Bay Buccaneers   8   8.919538  19            12
# 642   New England Patriots   8   8.918529  16            13
# 669       Seattle Seahawks   9   8.555919  10            14
# 662      Green Bay Packers   8   8.180089  18            15
# 666     New Orleans Saints   7   8.093090  24            16
# 645       Baltimore Ravens  10   7.897760   8            17
# 654      Las Vegas Raiders   6   7.714112  26            18
# 659  Washington Commanders   8   7.681525  17            19
# 646    Pittsburgh Steelers   9   7.460570  12            20
# 643          New York Jets   7   7.341014  22            21
# 658        New York Giants   9   7.309861  14            22
# 665      Carolina Panthers   7   7.084196  23            23
# 667        Atlanta Falcons   7   7.035387  25            24
# 647       Cleveland Browns   7   6.908686  20            25
# 649       Tennessee Titans   7   6.406431  21            26
# 670       Los Angeles Rams   5   6.321592  27            27
# 655         Denver Broncos   5   6.256163  28            28
# 651         Houston Texans   3   5.725705  31            29
# 671      Arizona Cardinals   4   5.414782  29            30
# 650     Indianapolis Colts   4   4.736960  30            31
# 663          Chicago Bears   3   2.605642  32            32

# %%
# going to try a logistic model to try for better accuracy

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg = LogisticRegression(max_iter=100)

# %%
# in this case, "train[predict] is my "X" train variable

# %%
# whereas train["W"] is my "y" train variable

# %%
logreg.fit(train[predict], train["W"])
# Out:
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# finally, "test[predict]" is my "X" test variable

# %%
log_predictions = logreg.predict(test[predict])

# %%
log_predictions = pd.DataFrame(log_predictions, columns=["predict"], index=test.index)

# %%
log_predictions
# Out:
#      predict
# 640       13
# 641        8
# 642        8
# 643        7
# 644       12
# 645       10
# 646        7
# 647        8
# 648       10
# 649        6
# 650        4
# 651        4
# 652       13
# 653        7
# 654        8
# 655        6
# 656       13
# 657       12
# 658        8
# 659        7
# 660        7
# 661       10
# 662        8
# 663        8
# 664        4
# 665        8
# 666        8
# 667        8
# 668       13
# 669        8
# 670        7
# 671        5

# %%
log_comb = pd.concat([test[["Tm", "W"]], log_predictions], axis=1)

# %%
log_comb = log_comb.sort_values("W", ascending=False)
log_comb["Rk"] = list(range(1,log_comb.shape[0]+1))

# %%
log_comb = log_comb.sort_values("predict", ascending=False)
log_comb["Predicted_Rk"] = list(range(1,log_comb.shape[0]+1))

# %%
log_comb
# Out:
#                         Tm   W  predict  Rk  Predicted_Rk
# 656    Philadelphia Eagles  14       13   1             1
# 652     Kansas City Chiefs  14       13   2             2
# 668    San Francisco 49ers  13       13   3             3
# 640          Buffalo Bills  13       13   5             4
# 657         Dallas Cowboys  12       12   6             5
# 644     Cincinnati Bengals  12       12   7             6
# 645       Baltimore Ravens  10       10   8             7
# 661          Detroit Lions   9       10  11             8
# 648   Jacksonville Jaguars   9       10  15             9
# 654      Las Vegas Raiders   6        8  26            10
# 667        Atlanta Falcons   7        8  25            11
# 666     New Orleans Saints   7        8  24            12
# 665      Carolina Panthers   7        8  23            13
# 647       Cleveland Browns   7        8  20            14
# 662      Green Bay Packers   8        8  18            15
# 663          Chicago Bears   3        8  32            16
# 642   New England Patriots   8        8  16            17
# 658        New York Giants   9        8  14            18
# 641         Miami Dolphins   9        8  13            19
# 669       Seattle Seahawks   9        8  10            20
# 643          New York Jets   7        7  22            21
# 646    Pittsburgh Steelers   9        7  12            22
# 653   Los Angeles Chargers  10        7   9            23
# 660      Minnesota Vikings  13        7   4            24
# 670       Los Angeles Rams   5        7  27            25
# 659  Washington Commanders   8        7  17            26
# 649       Tennessee Titans   7        6  21            27
# 655         Denver Broncos   5        6  28            28
# 671      Arizona Cardinals   4        5  29            29
# 664   Tampa Bay Buccaneers   8        4  19            30
# 650     Indianapolis Colts   4        4  30            31
# 651         Houston Texans   3        4  31            32

# %%
mean_squared_error(log_comb["W"], log_comb["predict"])
# Out:
# 3.5625

# %%
# I'm using mean squared error as opposed to other
# error metrics as I'm predicting where NFL franchises are going to finalize

# %%
# to wrap up this project, I'm going to implement
# backtesting to predict NFL franchise wins/year
# that way, if I want to place an early season playoff bet,
# I have an ML model to do so with relaively decent accuracy

# %%
years = list(range(2002,2022))

# %%
# this will return "total # of iterations reached"
# for every year. Probably could've done a Logistic Regression ML in 
# Google Collab - which may work better for this ML

# %%
aps = []
all_pred = []
all_log_comb = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    logreg = LogisticRegression(max_iter=100)
    logreg.fit(train[predict], train["W"])
    log_predictions = logreg.predict(test[predict])
    log_predictions = pd.DataFrame(log_predictions, columns=["predict"], index=test.index)
    log_comb = pd.concat([test[["Tm", "W"]], log_predictions], axis=1)
    all_pred.append(logreg)
    all_log_comb.append(log_comb)
# Out:
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
def add_rank_win(log_comb):
    log_comb = log_comb.sort_values("W", ascending=False)
    log_comb["Rk"] = list(range(1, log_comb.shape[0] + 1))
    log_comb = log_comb.sort_values("predict", ascending=False)
    log_comb["Predicted_Rk"] = list(range(1, log_comb.shape[0] + 1))
    log_comb["Diff_Rk"] = log_comb["Rk"] - log_comb["Predicted_Rk"]
    
    log_comb = log_comb.sort_values("W", ascending=False)
    log_comb = log_comb.sort_values("predict", ascending=False)
    log_comb["Diff_Wins"] = log_comb["W"] - log_comb["predict"]
    return log_comb

# %%
add_rank_win(all_log_comb[8])
# Out:
#                         Tm   W  predict  Rk  Predicted_Rk  Diff_Rk  Diff_Wins
# 444      Arizona Cardinals  13       13   2             1        1          0
# 421    Pittsburgh Steelers  10       13   9             3        6         -3
# 416   New England Patriots  12       13   3             2        1         -1
# 440      Carolina Panthers  15       12   1             4       -3          3
# 420     Cincinnati Bengals  12       12   5             5        0          0
# 445       Seattle Seahawks  10       12   8             6        2         -2
# 429     Kansas City Chiefs  11       11   7             7        0          0
# 436      Minnesota Vikings  11       10   6             8       -2          1
# 417          New York Jets  10       10  11             9        2          0
# 428         Denver Broncos  12        9   4            10       -6          3
# 437      Green Bay Packers  10        9  10            11       -1          1
# 424         Houston Texans   9        9  13            12        1          0
# 434        New York Giants   6        8  22            15        7         -2
# 435         Dallas Cowboys   4        8  29            21        8         -4
# 426   Jacksonville Jaguars   5        8  28            19        9         -3
# 439          Chicago Bears   6        8  25            13       12         -2
# 443   Tampa Bay Buccaneers   6        8  24            14       10         -2
# 442     New Orleans Saints   7        8  21            16        5         -1
# 441        Atlanta Falcons   8        8  14            17       -3          0
# 418          Buffalo Bills   8        8  16            18       -2          0
# 432  Washington Commanders   9        8  12            20       -8          1
# 433    Philadelphia Eagles   7        7  20            22       -2          0
# 430      Las Vegas Raiders   7        6  18            23       -5          1
# 446       Los Angeles Rams   7        6  19            24       -5          1
# 419         Miami Dolphins   6        6  23            25       -2          0
# 438          Detroit Lions   7        4  17            28      -11          3
# 425     Indianapolis Colts   8        4  15            31      -16          4
# 422       Baltimore Ravens   5        4  27            29       -2          1
# 447    San Francisco 49ers   5        4  26            30       -4          1
# 431   Los Angeles Chargers   4        4  30            27        3          0
# 423       Cleveland Browns   3        4  31            26        5         -1
# 427       Tennessee Titans   3        4  32            32        0         -1

# %%
def backtest(stats, years, predict):
    aps = []
    all_pred = []
    all_log_comb = []

    for year in years[5:]:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]

        logreg = LogisticRegression(max_iter=100)
        logreg.fit(train[predict], train["W"])
        log_predictions = logreg.predict(test[predict])
        log_predictions = pd.DataFrame(log_predictions, columns=["predict"], index=test.index)
        log_comb = pd.concat([test[["Tm", "W"]], log_predictions], axis=1)
        log_comb = add_rank_win(log_comb)
        all_pred.append(logreg)
        all_log_comb.append(log_comb)
        ap = find_ap(log_comb)
        aps.append(ap)

    mean_ap = sum(aps) / len(aps)

    return mean_ap, aps, all_pred

# %%
mean_ap, aps, all_pred = backtest(stats, years, predict)
# Out:
# /Users/elijahmclaughlin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 mean_ap, aps, all_pred = backtest(stats, years, predict)
#
# Cell In[63], line 18, in backtest(stats, years, predict)
#      16     all_pred.append(logreg)
#      17     all_log_comb.append(log_comb)
# ---> 18     ap = find_ap(log_comb)
#      19     aps.append(ap)
#      21 mean_ap = sum(aps) / len(aps)
#
# NameError: name 'find_ap' is not defined

# %%
# predicting 2023 season using the trained ML model

# %%
import random

# %%
test_predictions = logreg.predict(test[predict])

# %%
predictions_2022 = pd.DataFrame({"Team": test["Tm"], "Predicted Wins 2022": test_predictions})

# %%
predictions_2022 = predictions_2022.sort_values(by="Predicted Wins 2022", ascending=False)

# %%
n_iterations = 1000

# %%
all_random_predictions = []

for _ in range(n_iterations):
    random_test = test.sample(n=len(test), replace=True)
    random_test_predictions = logreg.predict(random_test[predict])

    random_predictions_2023 = pd.DataFrame({"Team": random_test["Tm"], "Predicted Wins 2023": random_test_predictions})

    random_predictions_2023 = random_predictions_2023.sort_values(by="Predicted Wins 2023", ascending=False)

    all_random_predictions.append(random_predictions_2023)

# %%
mean_predictions_2023 = pd.concat(all_random_predictions).groupby("Team").mean().reset_index()

# %%
mean_predictions_2023 = mean_predictions_2023.sort_values(by="Predicted Wins 2023", ascending=False)

# %%
print(mean_predictions_2023)
# Out:
#                      Team  Predicted Wins 2023
# 18       Los Angeles Rams                 13.0
# 11      Green Bay Packers                 13.0
# 29   Tampa Bay Buccaneers                 13.0
# 6      Cincinnati Bengals                 13.0
# 21   New England Patriots                 12.0
# 3           Buffalo Bills                 12.0
# 15     Kansas City Chiefs                 12.0
# 8          Dallas Cowboys                 12.0
# 25    Philadelphia Eagles                 11.0
# 13     Indianapolis Colts                 11.0
# 27    San Francisco 49ers                 11.0
# 0       Arizona Cardinals                 11.0
# 30       Tennessee Titans                 10.0
# 9          Denver Broncos                 10.0
# 22     New Orleans Saints                  9.0
# 28       Seattle Seahawks                  8.0
# 20      Minnesota Vikings                  8.0
# 7        Cleveland Browns                  8.0
# 2        Baltimore Ravens                  8.0
# 16      Las Vegas Raiders                  7.0
# 19         Miami Dolphins                  7.0
# 17   Los Angeles Chargers                  7.0
# 10          Detroit Lions                  7.0
# 5           Chicago Bears                  7.0
# 31  Washington Commanders                  7.0
# 4       Carolina Panthers                  5.0
# 1         Atlanta Falcons                  4.0
# 23        New York Giants                  4.0
# 24          New York Jets                  4.0
# 14   Jacksonville Jaguars                  4.0
# 26    Pittsburgh Steelers                  4.0
# 12         Houston Texans                  4.0
